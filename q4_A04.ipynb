# %% [markdown]
# <a href="https://colab.research.google.com/github/NamalSanjaya/CV_A04/blob/main/q4_A04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step

# %%
K = len(np.unique(y_train)) # Classes
Ntr = x_train.shape[0]

Nte = x_test.shape[0]
Din = 3072 # CIFAR10
# Din = 784 # MINIST

# Normalize pixel values

x_train, x_test = x_train / 255.0, x_test / 255.0
mean_image = np.mean(x_train, axis=0)
x_train = x_train - mean_image
x_test = x_test - mean_image

y_train = tf.keras.utils.to_categorical(y_train, num_classes=K)
y_test = tf.keras.utils.to_categorical(y_test, num_classes=K)
# x_train = np.reshape(x_train,(Ntr,Din))
# x_test = np.reshape(x_test,(Nte,Din))
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# %%
## CNN 

model = keras.models.Sequential()

model.add(keras.layers.Conv2D(32, (3,3), activation='relu', input_shape = (32,32,3) ))
model.add( keras.layers.MaxPooling2D((2,2)) )

model.add( keras.layers.Conv2D(64, (3,3),activation='relu') )
model.add( keras.layers.MaxPooling2D((2,2)) )

model.add(  keras.layers.Conv2D(64, (3,3),activation='relu') )
model.add( keras.layers.MaxPooling2D( (2,2)) )

model.add( keras.layers.Flatten() )

model.add( keras.layers.Dense(64, activation='sigmoid') )
model.add( keras.layers.Dense(10, activation='sigmoid') )

# %%
## Summary of the Network

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                16448
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 73,418
# Trainable params: 73,418
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
## Traning CNN

model.compile( optimizer= tf.keras.optimizers.SGD( learning_rate=0.01 , momentum=0.9) , 
              loss='CategoricalCrossentropy' , 
              metrics = ['accuracy'] )

# %%
model.fit( x_train, y_train , epochs=30 , batch_size=50 )
# Out:
# Epoch 1/30
# 1000/1000 [==============================] - 65s 64ms/step - loss: 2.1071 - accuracy: 0.2132
# Epoch 2/30
# 1000/1000 [==============================] - 63s 63ms/step - loss: 1.5158 - accuracy: 0.4509
# Epoch 3/30
# 1000/1000 [==============================] - 62s 62ms/step - loss: 1.2916 - accuracy: 0.5360
# Epoch 4/30
# 1000/1000 [==============================] - 62s 62ms/step - loss: 1.1361 - accuracy: 0.5983
# Epoch 5/30
# 1000/1000 [==============================] - 62s 62ms/step - loss: 1.0281 - accuracy: 0.6382
# Epoch 6/30
# 1000/1000 [==============================] - 63s 63ms/step - loss: 0.9322 - accuracy: 0.6716
# Epoch 7/30
# 1000/1000 [==============================] - 62s 62ms/step - loss: 0.8729 - accuracy: 0.6952
# Epoch 8/30
# 1000/1000 [==============================] - 62s 62ms/step - loss: 0.8059 - accuracy: 0.7175
# Epoch 9/30
# 1000/1000 [==============================] - 62s 62ms/step - loss: 0.7547 - accuracy: 0.7359
# Epoch 10/30
# 1000/1000 [==============================] - 66s 66ms/step - loss: 0.6975 - accuracy: 0.7578
# Epoch 11/30
# 1000/1000 [==============================] - 64s 64ms/step - loss: 0.6556 - accuracy: 0.7703
# Epoch 12/30
# 1000/1000 [==============================] - 64s 64ms/step - loss: 0.6191 - accuracy: 0.7849
# Epoch 13/30
# 1000/1000 [==============================] - 63s 63ms/step - loss: 0.5853 - accuracy: 0.7938
# Epoch 14/30
# 1000/1000 [==============================] - 63s 63ms/step - loss: 0.5459 - accuracy: 0.8086
# Epoch 15/30
# 1000/1000 [==============================] - 63s 63ms/step - loss: 0.5128 - accuracy: 0.8229
# Epoch 16/30
# 1000/1000 [==============================] - 64s 64ms/step - loss: 0.4837 - accuracy: 0.8328
# Epoch 17/30
# 1000/1000 [==============================] - 64s 64ms/step - loss: 0.4565 - accuracy: 0.8399
# Epoch 18/30
# 1000/1000 [==============================] - 63s 63ms/step - loss: 0.4309 - accuracy: 0.8493
# Epoch 19/30
# 1000/1000 [==============================] - 66s 66ms/step - loss: 0.3941 - accuracy: 0.8644
# Epoch 20/30
# 1000/1000 [==============================] - 65s 65ms/step - loss: 0.3787 - accuracy: 0.8686
# Epoch 21/30
# 1000/1000 [==============================] - 64s 64ms/step - loss: 0.3658 - accuracy: 0.8738
# Epoch 22/30
# 1000/1000 [==============================] - 64s 64ms/step - loss: 0.3388 - accuracy: 0.8849
# Epoch 23/30
# 1000/1000 [==============================] - 64s 64ms/step - loss: 0.3214 - accuracy: 0.8895
# Epoch 24/30
# 1000/1000 [==============================] - 65s 65ms/step - loss: 0.3066 - accuracy: 0.8975
# Epoch 25/30
# 1000/1000 [==============================] - 64s 64ms/step - loss: 0.2914 - accuracy: 0.8995
# Epoch 26/30
# 1000/1000 [==============================] - 64s 64ms/step - loss: 0.2739 - accuracy: 0.9065
# Epoch 27/30
# 1000/1000 [==============================] - 64s 64ms/step - loss: 0.2679 - accuracy: 0.9076
# Epoch 28/30
# 1000/1000 [==============================] - 63s 63ms/step - loss: 0.2511 - accuracy: 0.9153
# Epoch 29/30
# 1000/1000 [==============================] - 64s 64ms/step - loss: 0.2450 - accuracy: 0.9165
# Epoch 30/30
# 1000/1000 [==============================] - 64s 64ms/step - loss: 0.2366 - accuracy: 0.9194

# %%
model.evaluate(x_test , y_test , batch_size = 50 )
# Out:
# 200/200 [==============================] - 4s 19ms/step - loss: 1.0812 - accuracy: 0.7107
# [1.0812386274337769, 0.7106999754905701]
